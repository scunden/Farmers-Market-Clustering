# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', 500)
from matplotlib import pyplot as plt
from sklearn.datasets.samples_generator import make_blobs
from sklearn.cluster import KMeans
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:144: FutureWarning: The sklearn.datasets.samples_generator module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.datasets. Anything that cannot be imported from sklearn.datasets is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
df = pd.read_csv('farmers_markets_from_usda.csv')

# %%
df.head()
# Out:
#       FMID                                        MarketName  \
# 0  1018261   Caledonia Farmers Market Association - Danville
# 1  1018318                 Stearns Homestead Farmers' Market
# 2  1009364                 106 S. Main Street Farmers Market
# 3  1010691               10th Steet Community Farmers Market
# 4  1002454                              112st Madison Avenue
#
#                                              Website  \
# 0  https://sites.google.com/site/caledoniafarmers...
# 1                    http://www.StearnsHomestead.com
# 2             http://thetownofsixmile.wordpress.com/
# 3                                                NaN
# 4                                                NaN
#
#                                             Facebook Twitter Youtube  \
# 0  https://www.facebook.com/Danville.VT.Farmers.M...     NaN     NaN
# 1                      StearnsHomesteadFarmersMarket     NaN     NaN
# ...

# %%
df.isna().sum()
# Out:
# FMID                0
# MarketName          0
# Website          3513
# Facebook         4614
# Twitter          7778
# Youtube          8636
# OtherMedia       7933
# street            287
# city               40
# County             36
# State               0
# zip               948
# Season1Date      3107
# Season1Time      2940
# Season2Date      8339
# Season2Time      8348
# Season3Date      8726
# Season3Time      8729
# Season4Date      8799
# Season4Time      8799
# x                  28
# y                  28
# Location         6290
# Credit              0
# WIC                 0
# WICcash             0
# SFMNP               0
# SNAP                0
# Organic             0
# Bakedgoods       2823
# Cheese           2823
# Crafts           2823
# Flowers          2823
# Eggs             2823
# Seafood          2823
# Herbs            2823
# Vegetables       2823
# Honey            2823
# Jams             2823
# Maple            2823
# Meat             2823
# ...

# %%
df.shape
# Out:
# (8804, 59)

# %%
goods = ['Organic', 'Bakedgoods',
       'Cheese', 'Crafts', 'Flowers', 'Eggs', 'Seafood', 'Herbs', 'Vegetables',
       'Honey', 'Jams', 'Maple', 'Meat', 'Nursery', 'Nuts', 'Plants',
       'Poultry', 'Prepared', 'Soap', 'Trees', 'Wine', 'Coffee', 'Beans',
       'Fruits', 'Grains', 'Juices', 'Mushrooms', 'PetFood', 'Tofu',
       'WildHarvested']

# %%
df.dropna(subset=goods, inplace=True)

# %%
df['Organic'].value_counts()
# Out:
# Y    2417
# -    2223
# N    1341
# Name: Organic, dtype: int64

# %%
for good in goods:
    print(good+': '+str(df[good].value_counts(normalize=True).loc['Y']))
# Out:
# Organic: 0.40411302457782977
# Bakedgoods: 0.881123557933456
# Cheese: 0.4903862230396255
# Crafts: 0.620799197458619
# Flowers: 0.6839993312155158
# Eggs: 0.7512121718776125
# Seafood: 0.24661427854873766
# Herbs: 0.7726132753720114
# Vegetables: 0.9734158167530513
# Honey: 0.8145795017555593
# Jams: 0.8080588530346096
# Maple: 0.32285570974753386
# Meat: 0.5540879451596723
# Nursery: 0.05350275873599732
# Nuts: 0.2957699381374352
# Plants: 0.6468817923424176
# Poultry: 0.4577829794348771
# Prepared: 0.6124393914061194
# Soap: 0.679819428189266
# Trees: 0.2740344424009363
# Wine: 0.17455275037619128
# Coffee: 0.3674970740678816
# Beans: 0.14746697876609263
# Fruits: 0.8252800535027587
# Grains: 0.14546062531349271
# Juices: 0.2543053001170373
# Mushrooms: 0.24745025915398763
# PetFood: 0.19695703059689015
# Tofu: 0.04029426517304799
# WildHarvested: 0.15114529342919245

# %%
df[goods].replace(
    to_replace=['Y'],
    value=1,
    inplace=True)

df[goods].replace(
    to_replace=['N'],
    value=0,
    inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4172: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,

# %%
goods
# Out:
# ['Organic',
#  'Bakedgoods',
#  'Cheese',
#  'Crafts',
#  'Flowers',
#  'Eggs',
#  'Seafood',
#  'Herbs',
#  'Vegetables',
#  'Honey',
#  'Jams',
#  'Maple',
#  'Meat',
#  'Nursery',
#  'Nuts',
#  'Plants',
#  'Poultry',
#  'Prepared',
#  'Soap',
#  'Trees',
#  'Wine',
#  'Coffee',
#  'Beans',
#  'Fruits',
#  'Grains',
#  'Juices',
#  'Mushrooms',
#  'PetFood',
#  'Tofu',
#  'WildHarvested']

# %%
for good in goods:    
    df[good].replace(('Y', 'N'), (1, 0), inplace=True)

# %%
df.head()
# Out:
#       FMID                                        MarketName  \
# 0  1018261   Caledonia Farmers Market Association - Danville
# 1  1018318                 Stearns Homestead Farmers' Market
# 3  1010691               10th Steet Community Farmers Market
# 4  1002454                              112st Madison Avenue
# 5  1011100                           12 South Farmers Market
#
#                                              Website  \
# 0  https://sites.google.com/site/caledoniafarmers...
# 1                    http://www.StearnsHomestead.com
# 3                                                NaN
# 4                                                NaN
# 5                http://www.12southfarmersmarket.com
#
#                                             Facebook          Twitter Youtube  \
# 0  https://www.facebook.com/Danville.VT.Farmers.M...              NaN     NaN
# 1                      StearnsHomesteadFarmersMarket              NaN     NaN
# ...
